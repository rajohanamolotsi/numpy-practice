# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
new_arr = arr.copy()

# %%
arr[0] = 42

# %%
arr, new_arr
# Out:
# (array([42,  2,  3,  4,  5]), array([1, 2, 3, 4, 5]))

# %%
arr = np.array([1, 2, 3, 4, 5])
new_arr = arr.view()

# %%
arr[0] = 42
new_arr, arr
# Out:
# (array([42,  2,  3,  4,  5]), array([42,  2,  3,  4,  5]))

# %%
new_arr[1] = 777

# %%
arr
# Out:
# array([ 42, 777,   3,   4,   5])

# %%
new_arr.base
# Out:
# array([ 42, 777,   3,   4,   5])

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
x, y = arr.copy(), arr.view()

# %%
y[0] = 42

# %%
arr
# Out:
# array([42,  2,  3,  4,  5])

# %%
x.base

# %%
y.base
# Out:
# array([42,  2,  3,  4,  5])

# %%
import numpy as np
original_array = np.array([1, 2, 3])
x = original_array.copy()
x[0] = 5 # I changed x not the original_array
print(original_array)
# Out:
# [1 2 3]
